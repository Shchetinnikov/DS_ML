# %%
import pandas as pd 
import numpy as np
import os
from sklearn.metrics import mean_squared_error as mse, r2_score as r2

# %%
df_res = pd.read_csv('../res_test.csv')
true_values = df_res['median_house_value']

# %%
os.listdir("./res_1")
# Out:
# ['211009_Vanyushkin_1.csv',
#  '211010_Vanyushkin_2.csv',
#  '211011_Lavrov_1.csv',
#  '211011_Pochestnev_1.csv',
#  '211011_Sinkevich_1.csv',
#  '211012_Golubev_1.csv',
#  '211012_Gulyaev_1.csv',
#  '211012_Gulyaev_2.csv',
#  '211012_Pochestnev_2.csv',
#  '211012_Vanyushkin_3.csv',
#  '211012_Vasenkov_1.csv',
#  '211013_Gulyaev_3.csv',
#  '211013_Kudryavtsev_1.csv',
#  '211013_Kudryavtsev_2.csv',
#  '211013_Kuzin_1.csv',
#  '211013_Pochestnev_3.csv',
#  '211013_Sinkevich_2.csv',
#  '211013_Vanyushkin_4.csv',
#  '211014_Antipov_1.csv',
#  '211015_Vanyushkin_5.csv',
#  '211213_Mandrov_1.csv',
#  '211411_Lavrov_2.csv']

# %%
res_list = []
cur_dict = {}

for elem in os.listdir("./res_1"):
    print(elem)
    df_test = pd.read_csv(f'./res_1/{elem}')
    pred_values = df_test['median_house_value']
    cur_dict['Att'] = elem
    cur_dict['Res'] = round(r2(true_values, pred_values), 5)
    res_list.append(cur_dict.copy())
    cur_duct = {}
# Out:
# 211009_Vanyushkin_1.csv
# 211010_Vanyushkin_2.csv
# 211011_Lavrov_1.csv
# 211011_Lavrov_2.csv
# 211011_Pochestnev_1.csv
# 211011_Sinkevich_1.csv
# 211012_Golubev_1.csv
# 211012_Gulyaev_1.csv
# 211012_Gulyaev_2.csv
# 211012_Pochestnev_2.csv
# 211012_Vanyushkin_3.csv
# 211012_Vasenkov_1.csv
# 211013_Gulyaev_3.csv
# 211013_Kudryavtsev_1.csv
# 211013_Kudryavtsev_2.csv
# 211013_Kuzin_1.csv
# 211013_Mandrov_1.csv
# 211013_Pochestnev_3.csv
# 211013_Pochestnev_4.csv
# 211013_Sinkevich_2.csv
# 211013_Vanyushkin_4.csv
# 211013_Zaychikova_1.csv
# 211014_Antipov_1.csv
# 211015_Vanyushkin_5.csv
# 211016_Vanyushkin_6.csv
# 211017_Vanyushkin_7.csv
# 211017_Vanyushkin_8.csv
# 211018_Golubev_2.csv
# 211020_Mandrov_2.csv
# 211020_Pavlov_1.csv
# 211020_Petrosyan_1.csv
# 211020_Vanyushkin_10.csv
# 211020_Vanyushkin_9.csv
# 211020_Vasenkov_2.csv
# 211021_Vanyushkin_11.csv
# 211026_Mandrov_3.csv

# %%
pd.DataFrame(res_list).sort_values('Res', ascending=False)
# Out:
#                          Att      Res
# 34  211021_Vanyushkin_11.csv  0.85044
# 22      211014_Antipov_1.csv  0.84808
# 32   211020_Vanyushkin_9.csv  0.84655
# 31  211020_Vanyushkin_10.csv  0.84216
# 24   211016_Vanyushkin_6.csv  0.83965
# 25   211017_Vanyushkin_7.csv  0.83959
# 11     211012_Vasenkov_1.csv  0.83867
# 26   211017_Vanyushkin_8.csv  0.83711
# 12      211013_Gulyaev_3.csv  0.83661
# 18   211013_Pochestnev_4.csv  0.83579
# 17   211013_Pochestnev_3.csv  0.83398
# 33     211020_Vasenkov_2.csv  0.83393
# 35      211026_Mandrov_3.csv  0.83376
# 8       211012_Gulyaev_2.csv  0.83332
# 29       211020_Pavlov_1.csv  0.83309
# 15        211013_Kuzin_1.csv  0.83282
# 19    211013_Sinkevich_2.csv  0.83200
# 1    211010_Vanyushkin_2.csv  0.83171
# 30    211020_Petrosyan_1.csv  0.83160
# 28      211020_Mandrov_2.csv  0.83134
# 7       211012_Gulyaev_1.csv  0.83024
# 21   211013_Zaychikova_1.csv  0.83014
# 16      211013_Mandrov_1.csv  0.82964
# 5     211011_Sinkevich_1.csv  0.82958
# 4    211011_Pochestnev_1.csv  0.82957
# 10   211012_Vanyushkin_3.csv  0.82924
# 0    211009_Vanyushkin_1.csv  0.82700
# 27      211018_Golubev_2.csv  0.82602
# 9    211012_Pochestnev_2.csv  0.82600
# 3        211011_Lavrov_2.csv  0.82473
# 6       211012_Golubev_1.csv  0.82233
# 14  211013_Kudryavtsev_2.csv  0.74797
# 13  211013_Kudryavtsev_1.csv  0.74797
# 23   211015_Vanyushkin_5.csv  0.73716
# 20   211013_Vanyushkin_4.csv  0.70353
# 2        211011_Lavrov_1.csv -0.67780
